# %% [markdown]
# # Stochastic Approximation- Robbins-Monro algorithm

# %% [markdown]
# This project implements **Robbins Monro algorithm** to solve the **Frozen Lake** environment, a classic discrete reinforcement learning problem.
