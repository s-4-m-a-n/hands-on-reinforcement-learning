# %% [markdown]
# # Space Invaders using Deep Q-learning (DQN)

# %% [markdown]
# https://github.com/DLR-RM/rl-baselines3-zoo

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# ...
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-y5w91q5q
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-y5w91q5q
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 22e3ff2450fd92033f7f032915e1f64894a09584
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 33.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 29.6 MB/s eta 0:00:00
# ...

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 2 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,471 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 118194 files and directories currently installed.)
# ...

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# ...
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
# ...

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Training

# %%
# %%writefile dqn.yml
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 1000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   n_timesteps: 10000
#   learning_starts: 1000
#   target_update_interval: 100
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# Out:
# Overwriting dqn.yml

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# 2026-04-30 16:11:58.409702: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-30 16:11:58.479674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 3216382950
# Loading hyperparameters from: dqn.yml
# ...

# %% [markdown]
# ## Evaluation

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 500  --folder logs/
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# usage: enjoy.py [-h] [--env ENV] [-f FOLDER]
#                 [--algo {a2c,ddpg,dqn,ppo,sac,td3,ars,crossq,qrdqn,tqc,trpo,ppo_lstm}]
#                 [-n N_TIMESTEPS] [--num-threads NUM_THREADS] [--n-envs N_ENVS]
#                 [--exp-id EXP_ID] [--verbose VERBOSE] [--no-render]
#                 [--deterministic] [--device DEVICE] [--load-best]
#                 [--load-checkpoint LOAD_CHECKPOINT] [--load-last-checkpoint]
#                 [--stochastic] [--norm-reward] [--seed SEED]
#                 [--reward-log REWARD_LOG]
#                 [--gym-packages GYM_PACKAGES [GYM_PACKAGES ...]]
# ...

# %%
# !python -m rl_zoo3.record_video --algo dqn --env SpaceInvadersNoFrameskip-v4 -f logs/ -n 500
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /content/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-500.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
# ...

# %%
from IPython.display import Video, display

video_path = '/content/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-500.mp4'

display(Video(video_path, embed=True, html_attributes="controls autoplay loop"))
# Out:
# <video controls autoplay loop  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
